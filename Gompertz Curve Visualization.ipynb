# %%
import numpy as np
from ipywidgets import interact
import matplotlib.pyplot as plt

t = np.arange(0,50,0.1)
def f(a, b, c):
    plt.plot(t,a*np.exp(-b*np.exp(-c*t)))
    plt.show()
interact(f, a=486720, b=6, c=0.14);
