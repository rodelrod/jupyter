# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/home/rodelrod/Downloads/sample-salesv3.xlsx")

# %%
df.dtypes
# Out:
# account number      int64
# name               object
# sku                object
# quantity            int64
# unit price        float64
# ext price         float64
# date               object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#    account number                         name       sku  quantity  \
# 0          740150                   Barton LLC  B1-20000        39
# 1          714466              Trantow-Barrows  S2-77896        -1
# 2          218895                    Kulas Inc  B1-69924        23
# 3          307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4          412290                Jerde-Hilpert  S2-34077         6
#
#    unit price  ext price                date
# 0       86.69    3380.91 2014-01-01 07:21:51
# 1       63.16     -63.16 2014-01-01 10:00:47
# 2       90.70    2086.10 2014-01-01 13:24:58
# 3       21.05     863.05 2014-01-01 15:05:22
# 4       83.21     499.26 2014-01-01 23:26:55

# %%
df[df["account number"]==307599]
# Out:
#       account number                         name       sku  quantity  \
# 3             307599  Kassulke, Ondricka and Metz  S1-65481        41
# 13            307599  Kassulke, Ondricka and Metz  S2-10342        17
# 34            307599  Kassulke, Ondricka and Metz  S2-78676        35
# 58            307599  Kassulke, Ondricka and Metz  B1-20000        22
# 70            307599  Kassulke, Ondricka and Metz  S2-10342        44
# 143           307599  Kassulke, Ondricka and Metz  S1-27722        32
# 248           307599  Kassulke, Ondricka and Metz  S1-93683        -1
# 250           307599  Kassulke, Ondricka and Metz  S2-34077        48
# 273           307599  Kassulke, Ondricka and Metz  S2-10342         4
# 287           307599  Kassulke, Ondricka and Metz  S1-50961        28
# 291           307599  Kassulke, Ondricka and Metz  S2-82423         5
# 323           307599  Kassulke, Ondricka and Metz  S2-83881        45
# 382           307599  Kassulke, Ondricka and Metz  S2-16558        46
# 386           307599  Kassulke, Ondricka and Metz  B1-65551        48
# 387           307599  Kassulke, Ondricka and Metz  S2-10342        37
# 462           307599  Kassulke, Ondricka and Metz  S2-83881        35
# 475           307599  Kassulke, Ondricka and Metz  B1-33087        10
# 498           307599  Kassulke, Ondricka and Metz  B1-05914        31
# 502           307599  Kassulke, Ondricka and Metz  S2-83881        35
# 560           307599  Kassulke, Ondricka and Metz  S2-10342         6
# 591           307599  Kassulke, Ondricka and Metz  S1-27722         3
# 617           307599  Kassulke, Ondricka and Metz  S2-82423        21
# 619           307599  Kassulke, Ondricka and Metz  S2-10342         1
# 653           307599  Kassulke, Ondricka and Metz  S2-34077        46
# 663           307599  Kassulke, Ondricka and Metz  B1-20000        41
# 668           307599  Kassulke, Ondricka and Metz  S2-16558        14
# 692           307599  Kassulke, Ondricka and Metz  S2-34077         2
# 694           307599  Kassulke, Ondricka and Metz  S1-93683        48
# 809           307599  Kassulke, Ondricka and Metz  S2-16558        18
# 822           307599  Kassulke, Ondricka and Metz  S2-82423        39
# ...              ...                          ...       ...       ...
# 919           307599  Kassulke, Ondricka and Metz  S1-30248        19
# 922           307599  Kassulke, Ondricka and Metz  S1-27722        34
# 946           307599  Kassulke, Ondricka and Metz  S1-93683        39
# 14          737550  Fritsch, Russel and Anderson  B1-53102        23
# 26          737550  Fritsch, Russel and Anderson  B1-53636        42
# 31          714466               Trantow-Barrows  B1-33087        32
#
#     unit price  ext price                date
# 0        86.69    3380.91 2014-01-01 07:21:51
# 2        90.70    2086.10 2014-01-01 13:24:58
# 14       71.56    1645.88 2014-01-04 08:57:48
# 26       42.06    1766.52 2014-01-08 00:02:11
# 31       19.56     625.92 2014-01-09 10:16:32

# %%
df[df["account number"].isin([714466,218895])].head()
# Out:
#    account number             name       sku  quantity  unit price  ext price  \
# 1          714466  Trantow-Barrows  S2-77896        -1       63.16     -63.16
# 2          218895        Kulas Inc  B1-69924        23       90.70    2086.10
# 5          714466  Trantow-Barrows  S2-77896        17       87.63    1489.71
# 6          218895        Kulas Inc  B1-65551         2       31.10      62.20
# 8          714466  Trantow-Barrows  S1-50961        22       84.09    1849.98
#
#                  date
# 1 2014-01-01 10:00:47
# 2 2014-01-01 13:24:58
# 5 2014-01-02 10:07:15
# 6 2014-01-02 10:57:23
# 8 2014-01-03 11:29:02

# %%
df.query('name == ["Kulas Inc","Barton LLC"]').head()
# Out:
#     account number        name       sku  quantity  unit price  ext price  \
# 0           740150  Barton LLC  B1-20000        39       86.69    3380.91
# 2           218895   Kulas Inc  B1-69924        23       90.70    2086.10
# 6           218895   Kulas Inc  B1-65551         2       31.10      62.20
# 33          218895   Kulas Inc  S1-06532         3       22.36      67.08
# 36          218895   Kulas Inc  S2-34077        16       73.04    1168.64
#
#                   date
# 0  2014-01-01 07:21:51
# 2  2014-01-01 13:24:58
# 6  2014-01-02 10:57:23
# 33 2014-01-09 23:58:27
# 36 2014-01-10 12:07:30

# %%
df[df['sku'].str.startswith('B1')].head()
# Out:
#     account number                          name       sku  quantity  \
# 0           740150                    Barton LLC  B1-20000        39
# 2           218895                     Kulas Inc  B1-69924        23
# 6           218895                     Kulas Inc  B1-65551         2
# 14          737550  Fritsch, Russel and Anderson  B1-53102        23
# 17          239344                    Stokes LLC  B1-50809        14
#
#     unit price  ext price                date
# 0        86.69    3380.91 2014-01-01 07:21:51
# 2        90.70    2086.10 2014-01-01 13:24:58
# 6        31.10      62.20 2014-01-02 10:57:23
# 14       71.56    1645.88 2014-01-04 08:57:48
# 17       16.23     227.22 2014-01-04 22:14:32

# %%
df["name"].unique()
# Out:
# array(['Barton LLC', 'Trantow-Barrows', 'Kulas Inc',
#        'Kassulke, Ondricka and Metz', 'Jerde-Hilpert', 'Koepp Ltd',
#        'Fritsch, Russel and Anderson', 'Kiehn-Spinka', 'Keeling LLC',
#        'Frami, Hills and Schmidt', 'Stokes LLC', 'Kuhn-Gusikowski',
#        'Herman LLC', 'White-Trantow', 'Sanford and Sons', 'Pollich LLC',
#        'Will LLC', 'Cronin, Oberbrunner and Spencer',
#        'Halvorson, Crona and Champlin', 'Purdy-Kunde'], dtype=object)

# %%
# Define the headers since the data does not have any
headers = ["symboling", "normalized_losses", "make", "fuel_type", "aspiration",
           "num_doors", "body_style", "drive_wheels", "engine_location",
           "wheel_base", "length", "width", "height", "curb_weight",
           "engine_type", "num_cylinders", "engine_size", "fuel_system",
           "bore", "stroke", "compression_ratio", "horsepower", "peak_rpm",
           "city_mpg", "highway_mpg", "price"]

# Read in the CSV file and convert "?" to NaN
df = pd.read_csv("http://mlr.cs.umass.edu/ml/machine-learning-databases/autos/imports-85.data",
                  header=None, names=headers, na_values="?" )
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration num_doors  \
# 0          3                NaN  alfa-romero       gas        std       two
# 1          3                NaN  alfa-romero       gas        std       two
# 2          1                NaN  alfa-romero       gas        std       two
# 3          2              164.0         audi       gas        std      four
# 4          2              164.0         audi       gas        std      four
#
#     body_style drive_wheels engine_location  wheel_base   ...     engine_size  \
# 0  convertible          rwd           front        88.6   ...             130
# 1  convertible          rwd           front        88.6   ...             130
# 2    hatchback          rwd           front        94.5   ...             152
# 3        sedan          fwd           front        99.8   ...             109
# 4        sedan          4wd           front        99.4   ...             136
#
#    fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 0         mpfi  3.47    2.68               9.0      111.0    5000.0       21
# 1         mpfi  3.47    2.68               9.0      111.0    5000.0       21
# 2         mpfi  2.68    3.47               9.0      154.0    5000.0       19
# 3         mpfi  3.19    3.40              10.0      102.0    5500.0       24
# 4         mpfi  3.19    3.40               8.0      115.0    5500.0       18
#
#    highway_mpg    price
# 0           27  13495.0
# 1           27  16500.0
# 2           26  16500.0
# 3           30  13950.0
# 4           22  17450.0
#
# [5 rows x 26 columns]

# %%
df.dtypes
# Out:
# symboling              int64
# normalized_losses    float64
# make                  object
# fuel_type             object
# aspiration            object
# num_doors             object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_cylinders         object
# engine_size            int64
# fuel_system           object
# bore                 float64
# stroke               float64
# compression_ratio    float64
# horsepower           float64
# peak_rpm             float64
# city_mpg               int64
# highway_mpg            int64
# price                float64
# dtype: object

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#           make fuel_type aspiration num_doors   body_style drive_wheels  \
# 0  alfa-romero       gas        std       two  convertible          rwd
# 1  alfa-romero       gas        std       two  convertible          rwd
# 2  alfa-romero       gas        std       two    hatchback          rwd
# 3         audi       gas        std      four        sedan          fwd
# 4         audi       gas        std      four        sedan          4wd
#
#   engine_location engine_type num_cylinders fuel_system
# 0           front        dohc          four        mpfi
# 1           front        dohc          four        mpfi
# 2           front        ohcv           six        mpfi
# 3           front         ohc          four        mpfi
# 4           front         ohc          five        mpfi

# %%
obj_df[obj_df.isnull().any(axis=1)]
# Out:
#      make fuel_type aspiration num_doors body_style drive_wheels  \
# 27  dodge       gas      turbo       NaN      sedan          fwd
# 63  mazda    diesel        std       NaN      sedan          fwd
#
#    engine_location engine_type num_cylinders fuel_system
# 27           front         ohc          four        mpfi
# 63           front         ohc          four         idi

# %% [markdown]
# # Test
# This is a test
# * here we go
